# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/Nikhil Kumar/Downloads/Cars93.csv")

# %%
df.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                 NaN  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
# 1. How can you filter cars with horsepower greater than 200?

# %%
df[df['Horsepower']>200]
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 4    5            BMW      535i  Midsize       23.7   30.0       36.2
# 10  11       Cadillac   Seville  Midsize       37.5   40.1       42.7
# 18  19      Chevrolet  Corvette   Sporty       34.6   38.0       41.5
# 27  28          Dodge   Stealth   Sporty       18.5   25.8       33.1
# 29  30          Eagle    Vision    Large       17.5   19.3       21.2
# 47  48       Infiniti       Q45  Midsize       45.4   47.9       50.4
# 49  50          Lexus     SC300  Midsize       34.7   35.2       35.6
# 51  52        Lincoln  Town_Car    Large       34.4   36.1       37.8
# 56  57          Mazda      RX-7   Sporty       32.5   32.5       32.5
# 58  59  Mercedes-Benz      300E  Midsize       43.8   61.9       80.0
# 62  63     Mitsubishi  Diamante  Midsize       22.4   26.1       29.9
#
#     MPG.city  MPG.highway             AirBags  ... Passengers Length  \
# ...

# %%
df[['Manufacturer','Horsepower']][df['Horsepower']>200]
# Out:
#      Manufacturer  Horsepower
# 4             BMW         208
# 10       Cadillac         295
# 18      Chevrolet         300
# 27          Dodge         300
# 29          Eagle         214
# 47       Infiniti         278
# 49          Lexus         225
# 51        Lincoln         210
# 56          Mazda         255
# 58  Mercedes-Benz         217
# 62     Mitsubishi         202

# %%
# 2. Filter cars with horsepower less than or equal to 100.

# %%
df[df['Horsepower']<=100]
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 22  23        Dodge     Colt    Small        7.9    9.2       10.6        29
# 23  24        Dodge   Shadow    Small        8.4   11.3       14.2        23
# 24  25        Dodge   Spirit  Compact       11.9   13.3       14.7        22
# 26  27        Dodge  Dynasty  Midsize       14.8   15.6       16.4        21
# 28  29        Eagle   Summit    Small        7.9   12.2       16.5        29
# 30  31         Ford  Festiva    Small        6.9    7.4        7.9        31
# 32  33         Ford    Tempo  Compact       10.4   11.3       12.2        22
# 38  39          Geo    Metro    Small        6.7    8.4       10.0        46
# 39  40          Geo    Storm   Sporty       11.5   12.5       13.5        30
# 43  44      Hyundai    Excel    Small        6.8    8.0        9.2        29
# 45  46      Hyundai   Scoupe   Sporty        9.1   10.0       11.0        26
# ...

# %%
# 3. How can you extract cars with exactly 4 cylinders?

# %%
df[df['Cylinders']=='4']
# Out:
#     id   Manufacturer          Model     Type  Min.Price  Price  Max.Price  \
# 0    1          Acura        Integra    Small       12.9   15.9       18.8
# 4    5            BMW           535i  Midsize       23.7   30.0       36.2
# 5    6          Buick        Century  Midsize       14.2   15.7       17.3
# 11  12      Chevrolet       Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet        Corsica  Compact       11.4   11.4       11.4
# 14  15      Chevrolet         Lumina  Midsize       13.4   15.9       18.4
# 20  21       Chrysler        LeBaron  Compact       14.5   15.8       17.1
# 22  23          Dodge           Colt    Small        7.9    9.2       10.6
# 23  24          Dodge         Shadow    Small        8.4   11.3       14.2
# 24  25          Dodge         Spirit  Compact       11.9   13.3       14.7
# 26  27          Dodge        Dynasty  Midsize       14.8   15.6       16.4
# ...

# %%
# 4. Filter cars with a price higher than $25,000.

# %%
df[df['Price']>25]
# Out:
#     id   Manufacturer        Model     Type  Min.Price  Price  Max.Price  \
# 1    2          Acura       Legend  Midsize       29.2   33.9       38.7
# 2    3           Audi           90  Compact       25.9   29.1       32.3
# 3    4           Audi          100  Midsize       30.8   37.7       44.6
# 4    5            BMW         535i  Midsize       23.7   30.0       36.2
# 8    9          Buick      Riviera  Midsize       26.3   26.3       26.3
# 9   10       Cadillac      DeVille    Large       33.0   34.7       36.3
# 10  11       Cadillac      Seville  Midsize       37.5   40.1       42.7
# 18  19      Chevrolet     Corvette   Sporty       34.6   38.0       41.5
# 21  22       Chrysler     Imperial    Large       29.5   29.5       29.5
# 27  28          Dodge      Stealth   Sporty       18.5   25.8       33.1
# 47  48       Infiniti          Q45  Midsize       45.4   47.9       50.4
# 48  49          Lexus        ES300  Midsize       27.5   28.0       28.4
# ...

# %%
# 5. How can you extract cars with a weight between 3000 and 3500 lbs?

# %%
df[(df['Weight']>3000) & (df['Weight']<3500)]
# Out:
#     id Manufacturer         Model     Type  Min.Price  Price  Max.Price  \
# 2    3         Audi            90  Compact       25.9   29.1       32.3
# 3    4         Audi           100  Midsize       30.8   37.7       44.6
# 6    7        Buick       LeSabre    Large       19.9   20.8       21.7
# 8    9        Buick       Riviera  Midsize       26.3   26.3       26.3
# 13  14    Chevrolet        Camaro   Sporty       13.4   15.1       16.8
# 14  15    Chevrolet        Lumina  Midsize       13.4   15.9       18.4
# 18  19    Chevrolet      Corvette   Sporty       34.6   38.0       41.5
# 20  21     Chrysler       LeBaron  Compact       14.5   15.8       17.1
# 26  27        Dodge       Dynasty  Midsize       14.8   15.6       16.4
# 29  30        Eagle        Vision    Large       17.5   19.3       21.2
# 36  37         Ford        Taurus  Midsize       15.6   20.2       24.8
# 42  43        Honda        Accord  Compact       13.8   17.5       21.2
# ...

# %%
# 6. Filter cars manufactured in or after the year 2000.

# %%
# 7. How can you extract cars with an MPG.city greater than or equal to 25?

# %%
df[df['MPG.city']>=25]
# Out:
#     id Manufacturer     Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura   Integra    Small       12.9   15.9       18.8        25
# 11  12    Chevrolet  Cavalier  Compact        8.5   13.4       18.3        25
# 12  13    Chevrolet   Corsica  Compact       11.4   11.4       11.4        25
# 22  23        Dodge      Colt    Small        7.9    9.2       10.6        29
# 28  29        Eagle    Summit    Small        7.9   12.2       16.5        29
# 30  31         Ford   Festiva    Small        6.9    7.4        7.9        31
# 38  39          Geo     Metro    Small        6.7    8.4       10.0        46
# 39  40          Geo     Storm   Sporty       11.5   12.5       13.5        30
# 41  42        Honda     Civic    Small        8.4   12.1       15.8        42
# 43  44      Hyundai     Excel    Small        6.8    8.0        9.2        29
# 45  46      Hyundai    Scoupe   Sporty        9.1   10.0       11.0        26
# ...

# %%
# 8. Filter cars with an MPG.highway less than 20.

# %%
df[df['MPG.highway']<20]
# Out:
# Empty DataFrame
# Columns: [id, Manufacturer, Model, Type, Min.Price, Price, Max.Price, MPG.city, MPG.highway, AirBags, DriveTrain, Cylinders, EngineSize, Horsepower, RPM, Rev.per.mile, Man.trans.avail, Fuel.tank.capacity, Passengers, Length, Wheelbase, Width, Turn.circle, Rear.seat.room, Luggage.room, Weight, Origin, Make]
# Index: []
#
# [0 rows x 28 columns]

# %%
# 9. How can you extract cars that have a 'Type' of 'Sporty' or 'Compact'?

# %%
df[(df['Type']=='Sporty')|(df['Type']=='Compact')]
# Out:
#     id   Manufacturer     Model     Type  Min.Price  Price  Max.Price  \
# 2    3           Audi        90  Compact       25.9   29.1       32.3
# 11  12      Chevrolet  Cavalier  Compact        8.5   13.4       18.3
# 12  13      Chevrolet   Corsica  Compact       11.4   11.4       11.4
# 13  14      Chevrolet    Camaro   Sporty       13.4   15.1       16.8
# 18  19      Chevrolet  Corvette   Sporty       34.6   38.0       41.5
# 20  21       Chrysler   LeBaron  Compact       14.5   15.8       17.1
# 24  25          Dodge    Spirit  Compact       11.9   13.3       14.7
# 27  28          Dodge   Stealth   Sporty       18.5   25.8       33.1
# 32  33           Ford     Tempo  Compact       10.4   11.3       12.2
# 33  34           Ford   Mustang   Sporty       10.8   15.9       21.0
# 34  35           Ford     Probe   Sporty       12.8   14.0       15.2
# 39  40            Geo     Storm   Sporty       11.5   12.5       13.5
# ...

# %%
# 10. Filter cars that are either 'Domestic' or 'Imported'.

# %%
# 11. How can you extract cars with NaN values in the 'Rear.seat.room' column?

# %%
df[df['Rear.seat.room']=='NA']
# Out:
# Empty DataFrame
# Columns: [id, Manufacturer, Model, Type, Min.Price, Price, Max.Price, MPG.city, MPG.highway, AirBags, DriveTrain, Cylinders, EngineSize, Horsepower, RPM, Rev.per.mile, Man.trans.avail, Fuel.tank.capacity, Passengers, Length, Wheelbase, Width, Turn.circle, Rear.seat.room, Luggage.room, Weight, Origin, Make]
# Index: []
#
# [0 rows x 28 columns]

# %%
# 12. Filter cars that have a 'Manufacturer' name starting with the letter 'C'.

# %%
df[df['Manufacturer'].str[0]=='C']
# Out:
#     id Manufacturer       Model     Type  Min.Price  Price  Max.Price  \
# 9   10     Cadillac     DeVille    Large       33.0   34.7       36.3
# 10  11     Cadillac     Seville  Midsize       37.5   40.1       42.7
# 11  12    Chevrolet    Cavalier  Compact        8.5   13.4       18.3
# 12  13    Chevrolet     Corsica  Compact       11.4   11.4       11.4
# 13  14    Chevrolet      Camaro   Sporty       13.4   15.1       16.8
# 14  15    Chevrolet      Lumina  Midsize       13.4   15.9       18.4
# 15  16    Chevrolet  Lumina_APV      Van       14.7   16.3       18.0
# 16  17    Chevrolet       Astro      Van       14.7   16.6       18.6
# 17  18    Chevrolet     Caprice    Large       18.0   18.8       19.6
# 18  19    Chevrolet    Corvette   Sporty       34.6   38.0       41.5
# 19  20     Chrylser    Concorde    Large       18.4   18.4       18.4
# 20  21     Chrysler     LeBaron  Compact       14.5   15.8       17.1
# ...

# %%
# 13. How can you extract cars with 'AirBags' labeled as 'None'?

# %%
df[df['AirBags']=='None']
# Out:
# Empty DataFrame
# Columns: [id, Manufacturer, Model, Type, Min.Price, Price, Max.Price, MPG.city, MPG.highway, AirBags, DriveTrain, Cylinders, EngineSize, Horsepower, RPM, Rev.per.mile, Man.trans.avail, Fuel.tank.capacity, Passengers, Length, Wheelbase, Width, Turn.circle, Rear.seat.room, Luggage.room, Weight, Origin, Make]
# Index: []
#
# [0 rows x 28 columns]

# %%
# 14. Filter cars with 'Man.trans.avail' set to 'Yes'.

# %%
df[df['Man.trans.avail']=='Yes']
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0    1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1    2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2    3         Audi       90  Compact       25.9   29.1       32.3        20
# 3    4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4    5          BMW     535i  Midsize       23.7   30.0       36.2        22
# ..  ..          ...      ...      ...        ...    ...        ...       ...
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
# ...
